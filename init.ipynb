# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting umap-learn
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
# Collecting drawdata
#   Downloading drawdata-0.2.0-py2.py3-none-any.whl (2.0 kB)
# Collecting skope-rules
#   Downloading skope_rules-1.0.1-py3-none-any.whl (14 kB)
# Collecting streamlit
#   Downloading streamlit-0.80.0-py2.py3-none-any.whl (8.2 MB)
# Collecting jupyter>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: ipython>=7.16.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from drawdata->-r ./requirements.txt (line 3)) (7.22.0)
# Requirement already satisfied: traitlets>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (54.1.2)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (5.0.6)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: notebook in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (7.0.0.dev0)
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: nbconvert in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (6.0.7)
# Requirement already satisfied: ipykernel in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (5.5.3)
# Collecting ipywidgets
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting qtconsole
#   Downloading qtconsole-5.0.3-py3-none-any.whl (119 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from traitlets>=4.2->ipython>=7.16.1->drawdata->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: joblib>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-plot->-r ./requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: matplotlib>=1.4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-plot->-r ./requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: scikit-learn>=0.18 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-plot->-r ./requirements.txt (line 1)) (0.24.1)
# Requirement already satisfied: scipy>=0.9 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-plot->-r ./requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=1.4.0->scikit-plot->-r ./requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.18->scikit-plot->-r ./requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: pandas>=0.18.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skope-rules->-r ./requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.18.1->skope-rules->-r ./requirements.txt (line 4)) (2021.1)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (3.15.8)
# Requirement already satisfied: tornado>=5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (6.1)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: toml in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (0.10.2)
# Collecting tzlocal
#   Downloading tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# Collecting base58
#   Downloading base58-2.1.0-py3-none-any.whl (5.6 kB)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (20.9)
# Requirement already satisfied: pyarrow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (3.0.0)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.6.2-py2.py3-none-any.whl (4.2 MB)
# Collecting gitpython
#   Downloading GitPython-3.1.14-py3-none-any.whl (159 kB)
# Collecting watchdog
#   Downloading watchdog-2.0.3-py3-none-manylinux2014_x86_64.whl (74 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Requirement already satisfied: click>=7.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (7.1.2)
# Requirement already satisfied: altair>=3.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (4.1.0)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: cachetools>=4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from streamlit->-r ./requirements.txt (line 5)) (4.2.1)
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (0.3)
# Requirement already satisfied: jsonschema in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied: toolz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (0.11.1)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (6.1.12)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (5.1.3)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (4.7.1)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (3.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (0.17.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (22.0.3)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.9.4)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (20.1.0)
# Collecting numba>=0.49
#   Downloading numba-0.53.1-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.2.tar.gz (1.1 MB)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (1.14.5)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (2.20)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->jsonschema->altair>=3.2.0->streamlit->-r ./requirements.txt (line 5)) (3.7.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: async-generator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (1.10)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert->jupyter>=1.0.0->drawdata->-r ./requirements.txt (line 3)) (0.5.1)
# Collecting qtpy
#   Downloading QtPy-1.9.0-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit->-r ./requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit->-r ./requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit->-r ./requirements.txt (line 5)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->streamlit->-r ./requirements.txt (line 5)) (2020.12.5)
# Building wheels for collected packages: umap-learn, pynndescent, blinker
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76566 sha256=b8cd196a9fc2d54096c88ebaa6b1d74e3fb4058b7c6c7fb77fa66121f1bf85cd
#   Stored in directory: /root/.cache/pip/wheels/01/e7/bb/347dc0e510803d7116a13d592b10cc68262da56a8eec4dd72f
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.2-py3-none-any.whl size=51347 sha256=33b4e362a5f9d7b091a7d2c83534556c6e81073080cf6e09aebd8abbf4850857
#   Stored in directory: /root/.cache/pip/wheels/62/0b/55/40d651c5a4106ea9ce68d014335a1c7bf059530722c0107b15
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=8cc89d15be8f8956129cdbc796fcc0036a73207f3db75e39df0e3bfb51a1b827
#   Stored in directory: /root/.cache/pip/wheels/22/f5/18/df711b66eb25b21325c132757d4314db9ac5e8dabeaf196eab
# Successfully built umap-learn pynndescent blinker
# Installing collected packages: widgetsnbextension, smmap, qtpy, llvmlite, jupyterlab-widgets, qtconsole, numba, jupyter-console, ipywidgets, gitdb, watchdog, validators, tzlocal, pynndescent, pydeck, jupyter, gitpython, blinker, base58, astor, umap-learn, streamlit, skope-rules, scikit-plot, drawdata
# Successfully installed astor-0.8.1 base58-2.1.0 blinker-1.4 drawdata-0.2.0 gitdb-4.0.7 gitpython-3.1.14 ipywidgets-7.6.3 jupyter-1.0.0 jupyter-console-6.4.0 jupyterlab-widgets-1.0.0 llvmlite-0.36.0 numba-0.53.1 pydeck-0.6.2 pynndescent-0.5.2 qtconsole-5.0.3 qtpy-1.9.0 scikit-plot-0.3.7 skope-rules-1.0.1 smmap-4.0.0 streamlit-0.80.0 tzlocal-2.1 umap-learn-0.5.1 validators-0.18.2 watchdog-2.0.3 widgetsnbextension-3.5.1
# WARNING: You are using pip version 21.0.1; however, version 21.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4f5efaa1-5bc4-4195-979e-865992eb0408' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
